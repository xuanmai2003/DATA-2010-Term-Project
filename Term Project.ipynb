# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-09-14/billboard.csv'

billboard = pd.read_csv(url, index_col=0, parse_dates=[0])
billboard

url_1 = 'https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-09-14/audio_features.csv'
audio = pd.read_csv(url_1, index_col=0, parse_dates=[0])
audio
# Out:
#                                                                                        performer  \
# song_id
# -twistin'-White Silver SandsBill Black's Combo                                Bill Black's Combo
# ¿Dònde Està Santa Claus? (Where Is Santa Claus?...                                    Augie Rios
# ......And Roses And RosesAndy Williams                                             Andy Williams
# ...And Then There Were DrumsSandy Nelson                                            Sandy Nelson
# ...Baby One More TimeBritney Spears                                               Britney Spears
# ...                                                                                          ...
# Zoo YorkLil Tjay Featuring Fivio Foreign & Pop ...  Lil Tjay Featuring Fivio Foreign & Pop Smoke
# ZoomFuture                                                                                Future
# ...

# %%
df = billboard.join(audio.set_index('song_id', 'song', 'performer'), on='song_id', 'song', 'performer')
# Out:
#   File "C:\Users\admin\AppData\Local\Temp/ipykernel_8932/2350459205.py", line 1
#     df = billboard.join(audio.set_index('song_id', 'song', 'performer'), on='song_id', 'song', 'performer')
#                                                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
# Split data into train and test sets
from sklearn.model_selection import train_test_split

X = df.drop('peak_position', '', axis = 1)
y = df.peak_position

# We specify the random state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1,
                                                    random_state = 1234)

# %%
# Fit K-Nearest Neighbours
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors = 5)
# K = 5
model.fit(X_train, y_train)

# Get predicted values
y_pred = model.predict(X_test)
y_pred

# %%
import numpy as np

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

from sklearn.metrics import precision_score
precision_score(y_test, y_pred)

from sklearn.metrics import recall_score
recall_score(y_test, y_pred)
